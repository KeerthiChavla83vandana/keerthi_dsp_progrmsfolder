# %%
# BOLLYWOOD MOVIES DATA
import numpy as np
import pandas as pd

#reading bollwood csv data file

df=pd.read_csv("bollywood.csv")
df
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1    18-Apr-14                     2 States          LW    Romance
# 1       2     4-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N     Comedy
# 3       4     4-Jan-13             Rajdhani Express           N     Drama
# 4       5     4-Jul-14                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N     Comedy
# 145   146    13-Mar-15                         NH10           N   Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148    20-Mar-15                     Hunterrr           N     Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS     Action
#
# ...

# %%
# NO OF RECORDS IN THE BOLLYWOOD FILE
print("no of records:",len(df))
# Out:
# no of records: 149

# %%
rowcount=0
for row in open("bollywood.csv"):
    rowcount += 1
print(" no of records :",rowcount)

print("meta information:",df.info())
# Out:
#  no of records : 150
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SlNo                 149 non-null    int64
#  1   Release Date         149 non-null    object
#  2   MovieName            149 non-null    object
#  3   ReleaseTime          149 non-null    object
#  4   Genre                149 non-null    object
#  5   Budget               149 non-null    int64
#  6   BoxOfficeCollection  149 non-null    float64
#  7   YoutubeViews         149 non-null    int64
#  8   YoutubeLikes         149 non-null    int64
#  9   YoutubeDislikes      149 non-null    int64
#  10  MONTH                149 non-null    int64
#  11  year                 149 non-null    int64
#  12  ROI                  149 non-null    float64
# dtypes: float64(2), int64(7), object(4)
# memory usage: 15.3+ KB
# meta information: None

# %%
# NO OF RELESES IN EACH GONAR
genars=df.groupby(["Genre"])
print(genars.groups)

print("no of release in each genars: ",df.Genre.value_counts())

# which GONAR GOT HIGHEST NO OF RLEASES

print("printing hight no of moviees GENER:",df["Genre"].mode())

#SORTING GENRES IN DESENDING ORDER
print("gener in desending order:")
a=df.Genre.value_counts().tolist()
print(a)

print(df[["Genre","ReleaseTime"]].sort_values('ReleaseTime',ascending=False))
# Out:
# {' Drama ': [3, 5, 9, 23, 25, 26, 27, 29, 33, 34, 40, 49, 55, 56, 58, 63, 69, 70, 74, 76, 81, 86, 89, 101, 102, 104, 118, 120, 127, 128, 133, 134, 135, 139, 141], 'Action': [15, 22, 35, 36, 41, 43, 48, 54, 61, 77, 78, 91, 92, 100, 107, 119, 130, 136, 138, 143, 148], 'Action ': [10, 13, 21], 'Comedy': [2, 4, 6, 7, 8, 14, 17, 18, 19, 39, 46, 47, 52, 57, 59, 60, 65, 72, 75, 79, 84, 85, 87, 95, 96, 111, 112, 115, 124, 125, 126, 129, 132, 144, 146, 147], 'Romance': [0, 11, 12, 24, 32, 37, 42, 45, 50, 64, 66, 67, 80, 82, 83, 90, 97, 105, 106, 109, 110, 122, 123, 131, 142], 'Thriller': [28, 30, 31, 38, 44, 51, 53, 62, 68, 71, 73, 88, 93, 94, 98, 99, 103, 108, 113, 114, 116, 117, 121, 137, 140, 145], 'Thriller ': [1, 16, 20]}
# no of release in each genars:  Comedy       36
#  Drama       35
# Thriller     26
# Romance      25
# Action       21
# Thriller      3
# Action        3
# Name: Genre, dtype: int64
# printing hight no of moviees GENER: 0    Comedy
# dtype: object
# ...

# %%
#nof movied reeased each gonars within lingwikend,n,festv season etc

print(df.groupby(["Genre","ReleaseTime"]).groups)

print(df.groupby(["Genre","ReleaseTime"]).first())


no_of_mov_releasetime=df["Genre"].ReleaseTime.mode()

#pd.crosstab("Genre","ReleaseTime")
# Out:
# {(' Drama ', 'FS'): [23, 40, 127, 128], (' Drama ', 'HS'): [5, 29, 49, 55, 89, 133], (' Drama ', 'LW'): [26], (' Drama ', 'N'): [3, 9, 25, 27, 33, 34, 56, 58, 63, 69, 70, 74, 76, 81, 86, 101, 102, 104, 118, 120, 134, 135, 139, 141], ('Action', 'FS'): [92, 119, 143], ('Action', 'HS'): [36, 48, 148], ('Action', 'LW'): [61, 78, 130], ('Action', 'N'): [15, 22, 35, 41, 43, 54, 77, 91, 100, 107, 136, 138], ('Action ', 'N'): [10, 13, 21], ('Comedy', 'FS'): [115, 125, 126], ('Comedy', 'HS'): [17, 19, 39, 60, 85], ('Comedy', 'LW'): [8, 52, 59, 96, 132], ('Comedy', 'N'): [2, 4, 6, 7, 14, 18, 46, 47, 57, 65, 72, 75, 79, 84, 87, 95, 111, 112, 124, 129, 144, 146, 147], ('Romance', 'FS'): [106, 122, 142], ('Romance', 'HS'): [12, 32, 67], ('Romance', 'LW'): [0, 80, 83, 131], ('Romance', 'N'): [11, 24, 37, 42, 45, 50, 64, 66, 82, 90, 97, 105, 109, 110, 123], ('Thriller', 'FS'): [31, 62, 116, 121], ('Thriller', 'HS'): [99], ('Thriller', 'LW'): [114], ('Thriller', 'N'): [28, 30, 38, 44, 51, 53, 68, 71
# ...

# %%
print("no of movies in each Genre in each RELESE TIME")
print(df.Genre,df.ReleaseTime.value_counts())

pd.crosstab(df.Genre,df.ReleaseTime)
# Out:
# no of movies in each Genre in each RELESE TIME
# 0        Romance
# 1      Thriller
# 2         Comedy
# 3         Drama
# 4         Comedy
#          ...
# 144       Comedy
# 145     Thriller
# 146       Comedy
# 147       Comedy
# 148       Action
# Name: Genre, Length: 149, dtype: object N     99
# HS    18
# FS    17
# LW    15
# Name: ReleaseTime, dtype: int64
# ReleaseTime  FS  HS  LW   N
# Genre
#  Drama        4   6   1  24
# Action        3   3   3  12
# Action        0   0   0   3
# Comedy        3   5   5  23
# Romance       3   3   4  15
# Thriller      4   1   1  20
# Thriller      0   0   1   2

# %%
#4.Which month of the year, maximum number movie releases are seen? 
#(Note: Extract a new column called month from ReleaseDate column.)

# %%
# adding new colum as Monthname
import datetime 
df["MONTH"]=pd.DatetimeIndex(df['Release Date']).month
df['year']=pd.DatetimeIndex(df['Release Date']).year

df

# month name which is get more no of movies in a year
pd.crosstab(df.year,df.MONTH)

# to find modeof MONTH for each YEAR category, group all records by YEAR and then apply mODE() on MONTH column.

data=df.MONTH,df.year.value_counts()
data
# Out:
# (0      4
#  1      1
#  2      7
#  3      1
#  4      7
#        ..
#  144    2
#  145    3
#  146    3
#  147    3
#  148    5
#  Name: MONTH, Length: 149, dtype: int64,
#  2014    70
#  2013    67
#  2015    12
#  Name: year, dtype: int64)

# %% [markdown]
#  5. Which month of the year typically sees most releases of high budgeted movies, that is, movies with budget of 25 crore or more?

# %%
df[df['Budget']>=25][['MONTH','MovieName']]
# Out:
#      MONTH                    MovieName
# 0        4                     2 States
# 6        9                Daawat-E-Ishq
# 7        1   Matru Ki Bijlee Ka Mandola
# 8        1                 Dedh Ishqiya
# 10       3                  Dishkiyaoon
# ..     ...                          ...
# 139      1                   Hawaizaada
# 141      2                    Shamitabh
# 142      2                          Roy
# 146      3  Dilliwali Zaalim Girlfriend
# 148      5                Kochadaiiyaan
#
# [66 rows x 2 columns]

# %% [markdown]
# 6. Which are the top 10 movies with maximum return on investment (ROI)?
# Calculate return on investment (ROI) as (BoxOfficeCollection – Budget) / Budget

# %%
df['ROI']=(df['BoxOfficeCollection']-df['Budget'])/df['Budget']
df

df.nlargest(10,['ROI']).MovieName
# Out:
# 64                    Aashiqui 2
# 89                            PK
# 132                  Grand Masti
# 135                 The Lunchbox
# 87                        Fukrey
# 58                      Mary Kom
# 128                       Shahid
# 37     Humpty Sharma Ki Dulhania
# 101           Bhaag Milkha Bhaag
# 115              Chennai Express
# Name: MovieName, dtype: object

# %% [markdown]
#  7.Do the movies have higher ROI if they get released on festive seasons or long weekend?
#     Calculate the average ROI for different release times

# %%
df.nlargest(10,['ROI']).ReleaseTime
# Out:
# 64      N
# 89     HS
# 132    LW
# 135     N
# 87      N
# 58      N
# 128    FS
# 37      N
# 101     N
# 115    FS
# Name: ReleaseTime, dtype: object

# %%
print("Highest ROI vlaue movies release Time",df.nlargest(10,["ROI"]).ReleaseTime.mode())
# Out:
# Highest ROI vlaue movies release Time 0    N
# dtype: object

# %%
df.groupby(['ReleaseTime','ROI']).first()
# Out:
#                        SlNo Release Date                  MovieName     Genre  \
# ReleaseTime ROI
# FS          -0.926667   122     8-Nov-13                    Satya 2  Thriller
#             -0.833333   123    15-Nov-13                      Rajjo   Romance
#             -0.625000   127    11-Oct-13              Baat Ban Gayi    Comedy
#             -0.464286   126    11-Oct-13          War Chhod Na Yaar    Comedy
#             -0.363636   107    14-Mar-14               Bewakoofiyan   Romance
# ...                     ...          ...                        ...       ...
# N            5.500000    38    11-Jul-14  Humpty Sharma Ki Dulhania   Romance
#              5.933333    59     5-Sep-14                   Mary Kom    Drama
#              6.240000    88    14-Jun-13                     Fukrey    Comedy
#              7.500000   136    20-Sep-13               The Lunchbox    Drama
#              8.166667    65    26-Apr-13                 Aashiqui 2   Romance
#
# ...

# %%
#Average ROI for different release timesu
# we want mean for ROI col bseed on Release time

avg=df.groupby(["ReleaseTime"]).ROI.mean()
print(avg)
# Out:
# ReleaseTime
# FS    0.973853
# HS    0.850867
# LW    1.127205
# N     0.657722
# Name: ROI, dtype: float64
